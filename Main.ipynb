# %%
# %matplotlib inline
# Dependencies
# ----------------------------------

import pandas as pd
#import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from config import mysql_pass

# Imports the method used for connecting to DBs
from sqlalchemy import create_engine

# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float 

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()


from LoadFiles import get_dataframe

data_frame = pd.DataFrame()
try:
    data_frame = get_dataframe(True)    
except:
    print('File not found')

if data_frame.empty:
    print('Dataframe empty, please verify')
    #sys.exit()
else:        
    data_frame.head()
# Out:
# Change to <D:\Bootcamp\Project\DataBootCampProject02\input> directory
# Loading file <OpenBCI-RAW-2019-04-05_14-09-53.txt>...
# Dataframe generated

# %%
data_frame.head()
# Out:
#    RowNumber  Channel_1  Channel_2  Channel_3  Channel_4  Channel_5  \
# 0          0     709.62    -695.60     876.12    -555.65        0.0
# 1          1     828.65    -815.34     695.61    -205.56        0.0
# 2          2    1477.25    -370.52     403.40     638.65        0.0
# 3          3     944.63    -494.78    1008.48    -213.74        0.0
# 4          4     680.39    -853.11      71.79    -412.67        0.0
#
#    Channel_6  Channel_7           Time      TimeStamp
# 0        0.0        0.0   14:10:25.539  1554495025539
# 1        0.0        0.0   14:10:25.541  1554495025541
# 2        0.0        0.0   14:10:25.541  1554495025541
# 3        0.0        0.0   14:10:25.554  1554495025554
# 4        0.0        0.0   14:10:25.554  1554495025554

# %%
data_frame = data_frame.drop(columns=["RowNumber", "Channel_5",
            "Channel_6", "Channel_7"])

# %%
data_frame.head()
# Out:
#    Channel_1  Channel_2  Channel_3  Channel_4           Time      TimeStamp
# 0     709.62    -695.60     876.12    -555.65   14:10:25.539  1554495025539
# 1     828.65    -815.34     695.61    -205.56   14:10:25.541  1554495025541
# 2    1477.25    -370.52     403.40     638.65   14:10:25.541  1554495025541
# 3     944.63    -494.78    1008.48    -213.74   14:10:25.554  1554495025554
# 4     680.39    -853.11      71.79    -412.67   14:10:25.554  1554495025554

# %%
# Create Dog and Cat Classes
# ----------------------------------
#Base = declarative_base()

#class SignalData(Base):
#    __tablename__ = 'Data'
#    id = Column(Integer, primary_key=True)
#    channel_1 = Column(Float)
#    channel_2 = Column(Float)
#    channel_3 = Column(Float)
#    channel_4 = Column(Float)
#    Time = Column(String)
#    TimeStamp = Column(String)

# %%
#S1 = SignalData(channel_1 = 23.23)
print(mysql_pass)
# Out:
# my_r00tJ

# %%
#pymysql.install_as_MySQLdb()

engine = create_engine("mysql://root:"+mysql_pass+"@localhost/SignalData")
#engine = create_engine('hana+pyhdb://{}:{}@{}:{}'.format('system', 'mysql_pass', '192.168.56.101', '39015'))
#Sentencia de abajo funciona pero crea todo en la BD de systema con el usuario system
#engine = create_engine("hana://SignalData:J4n4.001@192.168.56.101:39015")

#engine = create_engine("hana://system:my_r00tJ@192.168.56.101:39015")
conn = engine.connect()

# %%
#from sqlalchemy.orm import Session
#session = Session(bind=engine)

# %%
#session.add(S1)

# %%
#session.commit()

# %%
data_frame.to_sql('data', con=engine, if_exists='replace')

# %%
engine.execute("SELECT count(1) FROM data").fetchall()
# Out:
# [(30484,)]

# %%
engine.execute("SELECT * FROM data").fetchall()
# Out:
# [(0, 709.62, -695.6, 876.12, -555.65, ' 14:10:25.539', 1554495025539),
#  (1, 828.65, -815.34, 695.61, -205.56, ' 14:10:25.541', 1554495025541),
#  (2, 1477.25, -370.52, 403.4, 638.65, ' 14:10:25.541', 1554495025541),
#  (3, 944.63, -494.78, 1008.48, -213.74, ' 14:10:25.554', 1554495025554),
#  (4, 680.39, -853.11, 71.79, -412.67, ' 14:10:25.554', 1554495025554),
#  (5, 1324.71, -530.4, -773.64, 477.5, ' 14:10:25.556', 1554495025556),
#  (6, 1273.83, -312.55, -254.33, 157.48, ' 14:10:25.556', 1554495025556),
#  (7, 632.32, -837.2, -540.24, -638.11, ' 14:10:25.569', 1554495025569),
#  (8, 1064.08, -698.16, -664.49, 126.04, ' 14:10:25.569', 1554495025569),
#  (9, 1525.47, -242.29, 85.59, 564.5, ' 14:10:25.585', 1554495025585),
#  (10, 744.18, -695.25, 860.49, 412.79, ' 14:10:25.585', 1554495025585),
#  (11, 863.88, -803.95, 696.94, 755.71, ' 14:10:25.586', 1554495025586),
#  (12, 1522.71, -356.28, 426.49, 1661.21, ' 14:10:25.586', 1554495025586),
# ...

# %%
conn.close()
